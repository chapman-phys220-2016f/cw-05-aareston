# %%
import pandas as pd
import matplotlib.pyplot as plt
import kinematics
# %matplotlib inline

df = pd.read_csv('accelerometer.csv')

#v_x = kinematics.velocity(df['t'],df[' Acceleration X (g)']-9.8)
#plt.plot(df['t'],v_x)
#v_y = kinematics.velocity(df['t'],df[' Acceleration Y (g)']-9.8)
#plt.plot(df['t'],v_y)
v_z = kinematics.velocity(df['t'],df[' Acceleration Scalar (g)'] - 1)
plt.plot(df['t'],v_z)

#r_x = kinematics.velocity(df['t'],v_x)
#plt.plot(df['t'],v_x)
#r_y = kinematics.velocity(df['t'],v_y)
#plt.plot(df['t'],v_y)
r_z = kinematics.velocity(df['t'],v_z)
plt.plot(df['t'],r_z)

# %%
v = df[' Speed (m/2)']
v -= v.data[0]
plt.plot(df['t'],v)

# %%
df.plot(0, y=3)
